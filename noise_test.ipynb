# %%
import numpy as np
from PIL import Image
from noise_utils import add_guassiannoise, add_poisson_noise, add_impulse_noise, get_poisson_std_from_g_sigma
import matplotlib.pyplot as plt
from skimage import metrics

# %%
img = Image.open('test.jpg')
img = np.asarray(img)

# %%
plt.imshow(img)
plt.show()

# %%
# noise = add_guassiannoise(img, 30)
noise = np.asarray(Image.open('boat_test_g/00000.png'))
print(metrics.peak_signal_noise_ratio(img, noise))
plt.imshow(noise)
plt.show()
# Out:
# 18.73059087089086

# %%
noise = np.asarray(Image.open('boat_test_p/00000.png'))
# noise = add_poisson_noise(img, 31.982421875)
print(metrics.peak_signal_noise_ratio(img, noise))
plt.imshow(noise)
plt.show()
# Out:
# 18.58101702964732

# %%
noise = np.asarray(Image.open('boat_test_sp/00000.png'))
# noise = add_impulse_noise(img, 0.12)
print(metrics.peak_signal_noise_ratio(img, noise))
plt.imshow(noise)
plt.show()
# Out:
# 18.74370800031131
